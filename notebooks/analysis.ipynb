# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
import pandas as pd
from src.cleaning import clean_data
from src.risk_model import compute_risk
from src.scoring import performance_scoring

df = pd.read_csv("../data/solar_systems.csv")

df = clean_data(df)
df = compute_risk(df)
df = performance_scoring(df)

df[['system_public_name', 'risk_score', 'risk_level', 'performance_index']]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 from src.cleaning import clean_data
#       3 from src.risk_model import compute_risk
#       4 from src.scoring import performance_scoring
#
# ModuleNotFoundError: No module named 'src'
